# %%
from src.stock_selection.sector_selection import select_stocks_by_sector

# Define a list of key stocks you want to ensure are included
key_stocks = ["AAPL", "IBM", "MSFT", "GOOGL"]

# Select top-performing stocks over the past years, with key stocks included
tickers = select_stocks_by_sector(stocks_per_sector=3, 
                                  ticker_file="data/selected_tickers.txt", 
                                  key_stocks=key_stocks,
                                  start_date="2018-01-01", 
                                  end_date="2023-01-01",
                                 test_start_date="2023-01-01",
                                 test_end_date="2024-01-01")

print("Selected Tickers for Analysis:", tickers)
# Out:
# S&P 500 sectors fetched successfully.
# Key stocks added
# Key stock: AAPL
# Key stock: IBM
# Key stock: MSFT
# Key stock: GOOGL
# c:\Users\Sarthak\Documents\GitHub\port\src\stock_selection\sector_selection.py:70: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data_test = yf.download(ticker, start=test_start_date, end=test_end_date)
# [*********************100%***********************]  1 of 1 completed
# c:\Users\Sarthak\Documents\GitHub\port\src\stock_selection\sector_selection.py:70: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data_test = yf.download(ticker, start=test_start_date, end=test_end_date)
# [*********************100%***********************]  1 of 1 completed
# c:\Users\Sarthak\Documents\GitHub\port\src\stock_selection\sector_selection.py:70: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data_test = yf.download(ticker, start=test_start_date, end=test_end_date)
# ...

# %%
from src.stock_selection.sector_selection import fetch_sp500_sectors
import yfinance as yf

# %%
sectors = fetch_sp500_sectors()

# %%
print(sectors.head())
